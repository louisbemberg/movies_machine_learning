# %% [markdown]
# ## Final Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../00_DATA/final_filtered_data.csv")
df = df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], errors="ignore")
df
# Out:
#          tconst               primaryTitle              originalTitle  \
# 0     tt0035423             Kate & Leopold             Kate & Leopold
# 1     tt0116391                       Gang                       Gang
# 2     tt0118589                    Glitter                    Glitter
# 3     tt0120166  The Sorcerer's Apprentice  The Sorcerer's Apprentice
# 4     tt0120467                     Vulgar                     Vulgar
# ...         ...                        ...                        ...
# 7901  tt9872052                      Eight                      Eight
# 7902  tt9875554                     Alaska                     Alaska
# 7903  tt9883996                Dream Horse                Dream Horse
# 7904  tt9892546                    Aladdin                    Aladdin
# 7905  tt9904802                Enemy Lines                Enemy Lines
#
#       isAdult  startYear  runtimeMinutes  Adult  Animation  Fantasy  \
# ...

# %% [markdown]
# ### Years since produced (reference: 2021)

# %%
df["yearsSinceProduced"] = 2021 - df["startYear"]
df.groupby("yearsSinceProduced").count()
# Out:
#                     tconst  primaryTitle  originalTitle  isAdult  startYear  \
# yearsSinceProduced
# 0                      204           204            204      204        204
# 1                      257           257            257      257        257
# 2                      465           465            465      465        465
# 3                      452           452            452      452        452
# 4                      477           477            477      477        477
# 5                      500           500            500      500        500
# 6                      446           446            446      446        446
# 7                      456           456            456      456        456
# 8                      420           420            420      420        420
# 9                      425           425            425      425        425
# 10                     435           435            435      435        435
# ...

# %% [markdown]
# ## Data Splitting

# %%
df_train = pd.DataFrame(df[df["startYear"] <= 2015])
df_test = pd.DataFrame(df[df["startYear"] > 2015])
assert(df_train.shape[0] + df_test.shape[0] == df.shape[0])

# %%
df_train["isTopActor"] = pd.Series([1 if x == True else 0 for x in df_train["isTopActor"]], index=df_train["isTopActor"].index)
df_train["isTopDirector"] = pd.Series([1 if x == True else 0 for x in df_train["isTopDirector"]], index=df_train["isTopDirector"].index)

df_test["isTopActor"] = pd.Series([1 if x == True else 0 for x in df_test["isTopActor"]], index=df_test["isTopActor"].index)
df_test["isTopDirector"] = pd.Series([1 if x == True else 0 for x in df_test["isTopDirector"]], index=df_test["isTopDirector"].index)
df_test
# Out:
#          tconst         primaryTitle                         originalTitle  \
# 639   tt0293429        Mortal Kombat                         Mortal Kombat
# 769   tt0315642                Wazir                                 Wazir
# 1281  tt0385887  Motherless Brooklyn                   Motherless Brooklyn
# 1649  tt0437086  Alita: Battle Angel                   Alita: Battle Angel
# 1674  tt0441881         Danger Close  Danger Close: The Battle of Long Tan
# ...         ...                  ...                                   ...
# 7901  tt9872052                Eight                                 Eight
# 7902  tt9875554               Alaska                                Alaska
# 7903  tt9883996          Dream Horse                           Dream Horse
# 7904  tt9892546              Aladdin                               Aladdin
# 7905  tt9904802          Enemy Lines                           Enemy Lines
#
# ...

# %%
# Rename columns
df_train = df_train.rename(columns={'Sci-Fi': 'SciFi', 'Talk-Show': 'TalkShow', 'Reality-TV': 'RealityTV', 'Game-Show': 'GameShow'})
df_test = df_test.rename(columns={'Sci-Fi': 'SciFi', 'Talk-Show': 'TalkShow', 'Reality-TV': 'RealityTV', 'Game-Show': 'GameShow'})

# %%
df_train = df_train.drop(columns=["Adult", "isAdult", "RealityTV", "Short", "TalkShow"])
df_test = df_test.drop(columns=["Adult", "isAdult", "RealityTV", "Short", "TalkShow"])
df_train
# Out:
#          tconst               primaryTitle              originalTitle  \
# 0     tt0035423             Kate & Leopold             Kate & Leopold
# 1     tt0116391                       Gang                       Gang
# 2     tt0118589                    Glitter                    Glitter
# 3     tt0120166  The Sorcerer's Apprentice  The Sorcerer's Apprentice
# 4     tt0120467                     Vulgar                     Vulgar
# ...         ...                        ...                        ...
# 7752  tt9020558             Hollywood Burn             Hollywood Burn
# 7755  tt9033128               Blood of War               Blood of War
# 7827  tt9345114                     Thirty                 Thalathoun
# 7836  tt9387330        I Love You as a Man             Lei si ai qing
# 7851  tt9546080                 Crazy Love                 Crazy Love
#
#       startYear  runtimeMinutes  Animation  Fantasy  GameShow  History  Music  \
# ...

# %%
df_train.to_csv("train_dataset.csv", index=False)
df_test.to_csv("test_dataset.csv", index=False)

# %% [markdown]
# Delete zeros columns: ["Adult", "isAdult", "RealityTV", "Short", "TalkShow"]

# %% [markdown]
# df
