# %%
import pandas as pd

# %%
data=pd.read_csv('revenue_actors.csv')

# %%
data
# Out:
#       Unnamed: 0     tconst               primaryTitle  \
# 0              0  tt0035423             Kate & Leopold
# 1           5062  tt0116391                       Gang
# 2           5778  tt0118589                    Glitter
# 3           6540  tt0120166  The Sorcerer's Apprentice
# 4           6682  tt0120467                     Vulgar
# ...          ...        ...                        ...
# 8055      147181  tt9872052                      Eight
# 8056      147192  tt9875554                     Alaska
# 8057      147224  tt9883996                Dream Horse
# 8058      147263  tt9892546                    Aladdin
# 8059      147334  tt9904802                Enemy Lines
#
#                   originalTitle  isAdult  startYear  runtimeMinutes  Adult  \
# 0                Kate & Leopold        0       2001             118      0
# 1                          Gang        0       2000             152      0
# 2                       Glitter        0       2001             104      0
# ...

# %%
#data_budget=data[(data['revenue']<10000) | (data['budget']<10000)]
data.drop(data[(data['revenue']<10000) | (data['budget']<10000)].index, inplace = True)
data.to_csv('final_filtered_data.csv')

# %%
        data_budget['budget'][i]=data_budget['budget'][i]*100000
    else
#data_budget['revenue']=data_budget['revenue']*1000000
# Out:
# /var/folders/4b/9yr63vtn00bfj8vq0m8bphhw0000gn/T/ipykernel_26410/3154635723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_budget['budget']=data_budget['budget']*1000000

# %%
data_budget
# Out:
#       Unnamed: 0     tconst                  primaryTitle  \
# 39          8411  tt0144084               American Psycho
# 128        10837  tt0183659                       Pollock
# 134        10932  tt0185007  Whispers: An Elephant's Tale
# 236        12653  tt0213203              Rugrats in Paris
# 536        15978  tt0276977                    Gang Tapes
# ...          ...        ...                           ...
# 7694      137512  tt7921182               Dead Man's Line
# 7782      139982  tt8364508                       Obscure
# 7961      144683  tt9260636                         Bigil
# 7983      145102  tt9358136                    The Sharks
# 7998      145468  tt9452824             Faces of the Dead
#
#                                  originalTitle  isAdult  startYear  \
# 39                             American Psycho        0       2000
# 128                                    Pollock        0       2000
# ...
